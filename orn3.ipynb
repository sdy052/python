# %%
gun='salı'
gun= input ('bgun
            
            
             giriniz.......:').lower)=
agr=float (input ('agr giriniz.......:'))

hesap=roud(agr/boy**2,2)
round()



if hesap <140:
    print(f'{hesap}karakter fazla') 
else:
    print(f'{hesap}karakter fazla')
# Out:
# 0.0karakter fazla
